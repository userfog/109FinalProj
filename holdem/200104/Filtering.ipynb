# %% [markdown]
# # Import Modules

# %%
import pandas as pd
import numpy as np
from nick_proj.script import get_data

# %% [markdown]
# # Use Nick's stuff in script.py to get dictionaries

# %% [markdown]
# ###### Is it worth it to go object oriented? Or just read from the text file?

# %%
# hands_dict, hand_rosters_dict, rounds_dict, winning_rounds_dict = get_data()
# print 'Done getting dictionaries!'
# Out:
# Done getting dictionaries!

# %% [markdown]
# # Make DataFrames

# %% [markdown]
# ### Do not uncomment and run! This takes a really long time!

# %%
# def make_df(data_dict, attr_names):
#     """
#     takes dictionary of objects and list of attribute names that will be the column headers
#     returns pandas DataFrame where attribute names are column headers and each object is one row
#     """
#     # create DataFrame
#     df = pd.DataFrame(columns = attr_names)
#     curr_row = 0
    
#     # add row for each object in the dictionary
#     for key in data_dict.keys():
#         # get object
#         entry = data_dict[key]
        
#         # create array of attributes to append to DataFrame
#         # iterate over list if value in dictionary is list
#         if isinstance(entry, list):
#             for elt in entry:
#                 record = [getattr(elt, attr) for attr in attr_names]
#                 df.loc[curr_row] = np.array(record, object)  
#                 curr_row += 1
#         else:
#             record = [getattr(entry, attr) for attr in attr_names]
#             df.loc[curr_row] = np.array(record, object)  
#             curr_row += 1
#     return df

# # columns (i.e. the attributes) for each dictionary
# hands_cols = ['timestamp', 'dealer', 'game_num', 'num_players_dealt_cards', 'num_players_flop',
#              'pot_size_flop', 'num_players_turn', 'pot_size_turn', 'num_players_river', 'pot_size_river',
#              'num_players_showdn', 'pot_size_showdn', 'board']
# hand_rosters_cols = ['timestamp', 'num_players', 'player_nicknames']
# rounds_cols = ['player', 'timestamp', 'num_players_dealt_cards', 'player_pos',
#                'bet_action_preflop', 'bet_action_flop', 'bet_action_turn', 'bet_action_river',
#                'start_bankroll', 'total_action', 'pot_amount_won', 'showdn_cards']

# %%
# # create a DataFrame for hands Dictionary
# hands = make_df(hands_dict, hands_cols)
# print 'Done with hand! Length :', len(hands)

# %%
# # create a DataFrame for hand_rosters Dictionary
# hand_rosters = make_df(hand_rosters_dict, hand_rosters_cols)
# print 'Done with hand_rosters! Length: ', len(hand_rosters)

# %%
# # create a DataFrame for rounds Dictionary
# rounds = make_df(rounds_dict, rounds_cols)
# print 'Done with rounds! Length: ', len(rounds)

# %%
# # create a DataFrame for winning_rounds Dictionary
# winning_rounds = make_df(winning_rounds_dict, rounds_cols)
# print 'Done with winning_rounds! Length:', len(winning_rounds)

# %% [markdown]
# ### Load Zach's Dataset for Testing

# %%
test_rounds = pd.read_csv('../../num_players_to_df/num_players_2.csv')
test_rounds.head()
# Out:
#    Unnamed: 0   player  timestamp  play  pos prflop flop turn river  bankroll  \
# 0          33   Johnny  986109383     2    1     Bc    b    -     -       160
# 1         131  pokibot  986109383     2    2     Bk    Q    -     -     15229
# 2           0      ATM  986109911     2    2     Bk    k    c     b      1000
# 3          34   Johnny  986109911     2    1     Bc    k    b    kc       170
# 4           1      ATM  986109946     2    1     Bc   kc   kc    kc      1000
#
#    action  winnings  c1  c2
# 0      20        30  XX  XX
# 1      10         0  XX  XX
# 2      50        50  2h  5d
# 3      50        50  5h  6h
# 4      60       120  Ac  8d

# %% [markdown]
# # Continuation Bet Filter

# %% [markdown]
# ### Right now, it works on Zach's num_players_2.csv file. But if you pass it any reasonable "round" DataFrame, it should work

# %%
def find_last_raise(string):
    """
    defined for use in cont_bet_filter. finds the last betting round that a raised happened given
    the string encoding a players actions, e.g. "Bcr"
    """
    return string.rfind('r')

def cont_bet_filter(df):
    """
    returns a dataframe containing only continuation bets from the DataFrame df
    """
    # remove duplicate timestamps
    timestamp_set = list(set(df['timestamp']))

    # create DataFrame with headers the same as for rounds
    cbets = pd.DataFrame(columns = df.columns.values)

    curr_row = 0
    
    for timestamp in timestamp_set:
        
        # get all entries associated with one hand/round
        curr_hand = df[df.timestamp == timestamp]
                
        # prflop_score lets us determine who the preflop raiser is. it takes the latest round of betting (0-indexed)
        # that someone raised and adds to it the player's position divided by 20
        # the player with the highest prflop_score greater than 0 is the preflop raiser
        # e.g. if BigBlind has actions 'Bcr', prflop_score will be 2.1 because latest raise was on 2nd round and he's
        # position 2. the position is divided by 20 because we only care about position if the latest bet of two players
        #is on the same round, and in this case, the higher position is the preflop raiser
        # dividing by 20 means we never add something >= 1
        curr_hand['prflop_score'] = curr_hand['prflop'].apply(find_last_raise) + (curr_hand['pos'] )/20.0
        
        # if the max prflop_score is less than 0, there is no preflop raiser
        if curr_hand['prflop_score'].max() > 0:
            
            # get the preflop raiser
            prflop_raiser_index = curr_hand['prflop_score'].argmax()
            prflop_raiser = curr_hand.loc[prflop_raiser_index]
            
            # if the preflop raiser bets on the flop, he is a c-better and we add him to the cbets DataFrame
            if prflop_raiser['flop'].find('b') == 0 or prflop_raiser['flop'].find('A') == 0:
                cbets.loc[curr_row] = prflop_raiser
                curr_row += 1
    return cbets
    
cont_bets = cont_bet_filter(test_rounds)

# %%
cont_bets.head()
# Out:
#   Unnamed: 0     player     timestamp play pos prflop flop turn river  \
# 0         64       DCAT  9.867756e+08    2   1     Br    b    b     -
# 1        393         pc  9.883813e+08    2   1     Br    b    -     -
# 2        347   FifthAve  9.883814e+08    2   2     Br    b    b     b
# 3        400         pc  9.883814e+08    2   2     Br    b    b     k
# 4        137  JoKannish  9.867758e+08    2   2     Br    b    b     k
#
#   bankroll action winnings  c1  c2
# 0     1087     50       80  XX  XX
# 1     2845     30       50  XX  XX
# 2     2374     70      140  Tc  9h
# 3     2720     50      100  9d  Kd
# 4     2026     50      100  Ts  Th

# %% [markdown]
# # 3-Bet Preflop Filter

# %%
def conatians_raise_or_all_in(s):
    return "r" in s or "A" in s

def three_bet_pre_flop(df):
    df = df.sort(["pos"])
    two_raises = 2
    for ind, row in df.iterrows():
        if conatians_raise_or_all_in(row.prflop):
            two_raises = two_raises - 1
        if two_raises == 0:
            return row
    return None
    
test_rounds = pd.read_csv('../../num_players_to_df/all_players.csv')
test_rounds = test_rounds.drop(["Unnamed: 0","Unnamed: 0.1"], axis=1)
test_rounds = test_rounds.groupby("timestamp").apply(three_bet_pre_flop)
test_rounds = test_rounds.dropna(thresh=1)
test_rounds.head(n=50)
# Out:
#            action  bankroll  c1  c2 flop  play     player  pos prflop river  \
# timestamp
# 986101403      40      1703  XX  XX    c     8  AJ-sOOted    6     rc     -
# 986101805     130      1393  Th  Kc    r     8  AJ-sOOted    8      r     r
# 986102031     100      1633  Kh  Kd    b     8  AJ-sOOted    6      r    kc
# 986102443     100      1215  Ks  Kh   bc     9   JohnSpot    7     rr    kc
# 986103460      90      1458  6h  Ad    r    10  AJ-sOOted    6      r     b
# 986104774     170     10852  Ah  As    r     8  flubnurd2    8      r     r
# 986104974     100      1421  XX  XX    r     9    SexyBoy    6     rc     b
# 986105050      70      2823  Qh  Qs    r     9   RobVegas    8      r     c
# 986105113      50      1376  XX  XX    f     9    SexyBoy    3     rc     -
# 986105399     100      2803  XX  XX   rc     8   RobVegas    4     rc    kf
# 986105860     110      2922  Ad  Kc    r     8    Regstar    4      r    kc
# 986106109     120       533  8d  Js   br     7  AJ-sOOted    5      r     c
# 986106427     150       777  XX  XX   br     7   hannibal    3     rc    kf
# 986106593      40       737  XX  XX    b     5   hannibal    5      r     -
# 986106623      90       792  3s  Jh    c     5   hannibal    4     rc     -
# 986106653     100      3056  Kh  Kc    c     4   RobVegas    3     rc     r
# 986106700     120       875  XX  XX    c     5   hannibal    5      r    rf
# 986106944     230      1968  2d  Ad   rr     4    SexyBoy    3     rc    rr
# 986107008      40       435  XX  XX    b     3   hannibal    3      r     -
# 986107049      60       545  XX  XX    r     3   hannibal    2    Brc     -
# 986107171      90       215  XX  XX   br     3   hannibal    3     rr     -
# 986107194     160     15944  Ah  Ad    r     3    pokibot    3     rr     c
# 986107274      30     15764  XX  XX    f     3    pokibot    3     rc     -
# 986107358      30     15719  XX  XX    f     3    pokibot    3     rc     -
# 986107756      50       715  XX  XX    k     8     Johnny    3     cr     b
# 986109325      90      2418  Kh  8d    b     4    SexyBoy    4     rr     -
# 986110118      90      1050  Ac  7h    c     2        ATM    2    Brc     c
# 986111025     100      1462  Jc  Js    r     5     smeagn    5     rr     b
# 986111270      30      2400  XX  XX    k     5      JP789    5     rc     -
# 986111303      50      2183  8h  8d   bc     5   Grizzler    5      r     k
